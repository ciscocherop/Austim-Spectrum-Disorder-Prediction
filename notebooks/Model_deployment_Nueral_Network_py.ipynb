# %% [markdown]
# <a href="https://colab.research.google.com/github/ciscocherop/Austim-Spectrum-Disorder-Prediction/blob/main/Model_deployment_Nueral_Network_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nueral Natwork

# %%
# !pip install -q streamlit

# %%
import streamlit as st
import joblib
import numpy as np
import tensorflow as tf

# %%
# Load model & scaler
scaler = "/content/scaler_nn.pkl"
model = "/content/neural_network_asd_model.keras"

st.title("ASD Traits Prediction App")
st.write("Enter the child's information to predict ASD Traits")

# -------------- INPUT FIELDS -----------------
A1 = st.selectbox("Routine / Struggle with Change (A1)", [0, 1])
A2 = st.selectbox("Maintain Eye Contact (A2)", [0, 1])
A3 = st.selectbox("Struggle with Social Interaction (A3)", [0, 1])
A4 = st.selectbox("Unusual Sensory Reactions (A4)", [0, 1])
A5 = st.selectbox("Repetitive Behaviors (A5)", [0, 1])
A6 = st.selectbox("Struggle to Understand Feelings (A6)", [0, 1])
A7 = st.selectbox("Prefer to Play Alone (A7)", [0, 1])
A8 = st.selectbox("Issues with Communication (A8)", [0, 1])
A9 = st.selectbox("Takes Language Literally (A9)", [0, 1])

SRS = st.slider("Social Responsiveness Scale Score (0–10)", 0, 10, 1)
QCHAT = st.slider("QCHAT Screening Score (0–10)", 0, 10, 1)

Speech_Delay = st.selectbox("Speech Delay / Language Disorder", [0, 1])
Learning_Disorder = st.selectbox("Learning Disorder", [0, 1])
Genetic_Disorders = st.selectbox("Genetic Disorders", [0, 1])
Depression = st.selectbox("Depression", [0, 1])
Global_Delay = st.selectbox("Global Developmental Delay / Intellectual Disability", [0, 1])
Social_Issues = st.selectbox("Social / Behavioural Issues", [0, 1])
CARS = st.slider("Childhood Autism Rating Scale (1–4)", 1, 4, 1)
Anxiety = st.selectbox("Anxiety Disorder", [0, 1])
Sex = st.selectbox("Sex (Male=1, Female=0)", [0, 1])
Jaundice = st.selectbox("Jaundice at Birth", [0, 1])
Family_ASD = st.selectbox("Family Member with ASD", [0, 1])

# ---------------- PREDICTION -------------------

input_data = np.array([[
    A1, A2, A3, A4, A5, A6, A7, A8, A9,
    SRS, QCHAT,
    Speech_Delay, Learning_Disorder, Genetic_Disorders,
    Depression, Global_Delay, Social_Issues,
    CARS, Anxiety,
    Sex, Jaundice, Family_ASD
]])

# Scale the input using the same scaler used during training
input_scaled = scaler.transform(input_data)

# -------------------- PREDICTION --------------------------

if st.button("Predict ASD Traits"):
    prediction = model.predict(input_scaled)[0]

    if prediction == 1:
        st.error("⚠️ The model predicts: **ASD Traits Present**")
    else:
        st.success("✅ The model predicts: **No ASD Traits**")
# Out:
# 2025-11-26 17:21:31.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.266 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.419 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.488 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-26 17:21:31.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2860973566.py in <cell line: 0>()
#      44
#      45 # Scale the input using the same scaler used during training
# ---> 46 input_scaled = scaler.transform(input_data)
#      47
#      48 # -------------------- PREDICTION --------------------------
#
# AttributeError: 'str' object has no attribute 'transform'

# %% [markdown]
# First, I'll write the Streamlit application code to a file named `app.py`.

# %%
# %%writefile app.py

import streamlit as st
import joblib
import numpy as np
import tensorflow as tf

# Load model & scaler
scaler = joblib.load("/content/scaler_nn.pkl")
model = tf.keras.models.load_model("/content/neural_network_asd_model.keras")

st.title("ASD Traits Prediction App")
st.write("Enter the child's information to predict ASD Traits")

# -------------- INPUT FIELDS -----------------
A1 = st.selectbox("Routine / Struggle with Change (A1)", [0, 1])
A2 = st.selectbox("Maintain Eye Contact (A2)", [0, 1])
A3 = st.selectbox("Struggle with Social Interaction (A3)", [0, 1])
A4 = st.selectbox("Unusual Sensory Reactions (A4)", [0, 1])
A5 = st.selectbox("Repetitive Behaviors (A5)", [0, 1])
A6 = st.selectbox("Struggle to Understand Feelings (A6)", [0, 1])
A7 = st.selectbox("Prefer to Play Alone (A7)", [0, 1])
A8 = st.selectbox("Issues with Communication (A8)", [0, 1])
A9 = st.selectbox("Takes Language Literally (A9)", [0, 1])

SRS = st.slider("Social Responsiveness Scale Score (0–10)", 0, 10, 1)
QCHAT = st.slider("QCHAT Screening Score (0–10)", 0, 10, 1)

Speech_Delay = st.selectbox("Speech Delay / Language Disorder", [0, 1])
Learning_Disorder = st.selectbox("Learning Disorder", [0, 1])
Genetic_Disorders = st.selectbox("Genetic Disorders", [0, 1])
Depression = st.selectbox("Depression", [0, 1])
Global_Delay = st.selectbox("Global Developmental Delay / Intellectual Disability", [0, 1])
Social_Issues = st.selectbox("Social / Behavioural Issues", [0, 1])
CARS = st.slider("Childhood Autism Rating Scale (1–4)", 1, 4, 1)
Anxiety = st.selectbox("Anxiety Disorder", [0, 1])
Sex = st.selectbox("Sex (Male=1, Female=0)", [0, 1])
Jaundice = st.selectbox("Jaundice at Birth", [0, 1])
Family_ASD = st.selectbox("Family Member with ASD", [0, 1])

# ---------------- PREDICTION -------------------

input_data = np.array([[
    A1, A2, A3, A4, A5, A6, A7, A8, A9,
    SRS, QCHAT,
    Speech_Delay, Learning_Disorder, Genetic_Disorders,
    Depression, Global_Delay, Social_Issues,
    CARS, Anxiety,
    Sex, Jaundice, Family_ASD
]])

# Scale the input using the same scaler used during training
input_scaled = scaler.transform(input_data)

# -------------------- PREDICTION --------------------------

if st.button("Predict ASD Traits"):
    prediction = model.predict(input_scaled)[0]

    if prediction == 1:
        st.error("⚠️ The model predicts: **ASD Traits Present**")
    else:
        st.success("✅ The model predicts: **No ASD Traits**")
# Out:
# Writing app.py

# %% [markdown]
# Now that `app.py` is created, I will run the Streamlit application.

# %%
# !streamlit run app.py
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.169.216:8501

# %%
# !streamlit run app.py
# Out:
# Usage: streamlit run [OPTIONS] [TARGET] [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: app.py
